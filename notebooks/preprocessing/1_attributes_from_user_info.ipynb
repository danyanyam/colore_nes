# %%
from src.utils import get_user_info, get_root_path

# %%
user_info = get_user_info()
attributes = user_info.iloc[:, 52:146]

target = attributes.loc[:, attributes.columns.str.endswith('_no')]
target.to_csv(get_root_path() / 'data/interim/attributes.csv')
target.head()
# Out:
#    charming_no  cheerful_no  confident_no  contemporary_no  cool_no  \
# 0            4            3             3                4        3
# 1            3            3             3                3        4
# 2            3            4             4                2        3
# 3            5            5             4                4        4
# 4            5            4             5                5        4
#
#    corporate_no  daring_no  different_no  distinctive_no  downToEarth_no  ...  \
# 0             2          2             5               4               2  ...
# 1             3          3             4               3               2  ...
# 2             2          3             4               2               4  ...
# 3             2          3             3               5               4  ...
# 4             5          5             5               5               5  ...
#
#    successful_no  technical_no  tough_no  trendy_no  unique_no  upToDate_no  \
# 0              3             4         3          2          2            3
# 1              4             2         2          3          4            3
# 2              4             4         3          3          4            2
# 3              5             4         1          5          5            4
# 4              5             1         2          5          5            5
#
#    upperClass_no  western_no  wholesome_no  young_no
# 0              2           2             4         3
# 1              2           4             4         4
# 2              3           2             2         2
# 3              5           5             4         4
# 4              3           5             5         4
#
# [5 rows x 47 columns]
